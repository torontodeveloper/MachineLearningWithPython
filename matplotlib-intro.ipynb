# %%
import numpy as np 
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import time

# %%
# %matplotlib inline

# %%
array1 = np.array([2.0,4.0])

# %%
print(array1.shape)
# Out:
# (2,)

# %%
len(array1)
# Out:
# 2

# %%
x_train = np.array([2.0,3.0])
y_train = np.array([300.0,500.0])
# %matplotlib inline

# %%
plt.scatter(x_train,y_train,marker='^',c='#8c564b')
plt.title('Scatter plot')
plt.xlabel('Features')
plt.ylabel('Target Variables')
plt.show()

# %%
f = np.zeros((2,3))

# %%
x_train
# Out:
# array([2., 3.])

# %%
size = x_train.shape[0]

# %%
f
# Out:
# array([[300., 300., 300.],
#        [400., 400., 400.]])

# %%
w=1
b = 0
for i in range(size):
    f[i]= wi*x_train[i]+bi  

    plt.plot(x_train,f,label='Predicted Values')
    plt.show
    plt.xlabel('size in 100sqft')
    plt.ylabel('Price ')
    plt.title('Regression')
    plt.scatter(x_train,y_train,marker='^',c='red',label='Data points')
    plt.legend()

# %%
np.random.randint(1,100,10)
# Out:
# array([ 4, 15, 87, 83, 32, 24, 83, 42, 53, 86], dtype=int32)

# %%
w = 200
b = 100
x_i = 1.2
cost_fn = w*x_i + b

# %%
print(f'cost function is {cost_fn} in thousands')
# Out:
# cost function is 340.0 in thousands
